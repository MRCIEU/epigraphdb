# %% [markdown]
# # EpigraphDB platform

# %% [markdown]
# In this notebook we show the following aspects of the EpiGraphDB platform, and how to use the API to get the information:
#
# 1. Metadata: meta nodes and meta edges, and the overall schema.
# 2. Search for a specific node under the meta node.
# 3. Cypher: how to query the database directly using Neo4j Cypher
#
# For detailed documentation on the API endpoints please visit:
#
# - The Swagger interface: http://api.epigraphdb.org
# - The sections regarding API endpoints on the documentation site: http://docs.epigraphdb.org/api/api-endpoints/

# %%
from pprint import pformat

import networkx as nx
import pandas as pd
import requests

# %%
API_URL = "http://api.epigraphdb.org"

requests.get(f"{API_URL}/ping").json()
# Out:
# True

# %% [markdown]
# ## Metadata

# %% [markdown]
# Here we query for the metadata information using the endpoint `GET /meta/schema`, which will be used for downstream processing.

# %%
endpoint = "/meta/schema"
params = {
    "graphviz": False,
    "plot": False
}
r = requests.get(f"{API_URL}{endpoint}", params=params)
r.raise_for_status()
metadata = r.json()

# Preview of metadata information
keys = metadata.keys()
print(pformat(keys), "\n")
for key in list(keys):
    print(f"# {key}:")
    print(pformat(metadata[key])[:1000], "\n")
# Out:
# dict_keys(['nodes', 'edges', 'connections'])
#
# # nodes:
# {'Disease': {'count': 3312,
#              'properties': {'doid': {'indexed': False,
#                                      'type': 'STRING',
#                                      'unique': False},
#                             'name': {'indexed': False,
#                                      'type': 'STRING',
#                                      'unique': False},
#                             'synonym': {'indexed': False,
#                                         'type': 'STRING',
#                                         'unique': False}}},
#  'Drug': {'count': 3061,
#           'properties': {'chembl_uri': {'indexed': False,
#                                         'type': 'STRING',
#                                         'unique': False},
#                          'label': {'indexed': True,
#                                    'type': 'STRING',
#                                    'unique': False},
#                          'molecule_type': {'indexed': False,
#                                            'type
#
# # edges:
# {'CPIC': {'count': 356,
#           'properties': {'cpic_level': {'array': False, 'type': 'STRING'},
#                          'guideline': {'array': False, 'type': 'STRING'},
#                          'pgx_on_fda_label': {'array': False, 'type': 'STRING'},
#                          'pharmgkb_level_of_evidence': {'array': False,
#                                                         'type': 'STRING'}}},
#  'DISEASE_TO_EFO': {'count': 1824, 'properties': None},
#  'DRUG_TO_DISEASE': {'count': 158, 'properties': None},
#  'DRUG_TO_LITERATURE': {'count': 243, 'properties': None},
#  'DRUG_TO_PROTEIN': {'count': 22438,
#                      'properties': {'relation': {'array': False,
#                                                  'type': 'STRING'},
#                                     'std_value': {'array': False,
#                                                   'type': 'STRING'}}},
#  'EFO_CHILD_OF': {'count': 26562, 'properties': None},
#  'EFO_EXACT': {'count': 363, 'properties': None},
#  'EFO_FUZZY':
#
# # connections:
# [{'count': 158,
#   'from_node': 'Drug',
#   'rel': 'DRUG_TO_DISEASE',
#   'to_node': 'Disease'},
#  {'count': 3318,
#   'from_node': 'MeshTerm',
#   'rel': 'MESH_TO_DISEASE',
#   'to_node': 'Disease'},
#  {'count': 1824,
#   'from_node': 'Disease',
#   'rel': 'DISEASE_TO_EFO',
#   'to_node': 'Efo'},
#  {'count': 12488,
#   'from_node': 'Pathway',
#   'rel': 'EVENT_IN_PATHWAY',
#   'to_node': 'Event'},
#  {'count': 8952,
#   'from_node': 'Pathway',
#   'rel': 'PATHWAY_TO_LITERATURE',
#   'to_node': 'Literature'},
#  {'count': 9281,
#   'from_node': 'Protein',
#   'rel': 'PROTEIN_IN_PATHWAY',
#   'to_node': 'Pathway'},
#  {'count': 3784757, 'from_node': 'Gene', 'rel': 'XQTL_MR', 'to_node': 'Gwas'},
#  {'count': 861552,
#   'from_node': 'Gene',
#   'rel': 'EXPRESSED_IN',
#   'to_node': 'Gtex'},
#  {'count': 18408, 'from_node': 'Snp', 'rel': 'SNP_GENE', 'to_node': 'Gene'},
#  {'count': 6045,
#   'from_node': 'Drug',
#   'rel': 'OPENTARGETS_DRUG_TO_TARGET',
#   'to_node': 'Gene'},
#  {'count': 356, 'from_node': 'Drug', 'rel': 'CPIC', 'to_node': 'Gene'},
#  {

# %% [markdown]
# ### Meta nodes
#
# We can extract the specific meta node information as a pandas dataframe from the metadata.

# %%
meta_node_df = pd.DataFrame.from_dict(
    metadata["nodes"], orient="index")

(
    meta_node_df
    .sort_index()
    .assign(count=lambda df: df["count"].apply(lambda x: f"{x:,}"))
)
# Out:
#                 count                                         properties
# Disease         3,312  {'name': {'type': 'STRING', 'indexed': False, ...
# Drug            3,061  {'phase': {'type': 'INTEGER', 'indexed': False...
# Efo            21,864  {'type': {'type': 'STRING', 'indexed': False, ...
# Event          11,868  {'in_disease': {'type': 'STRING', 'indexed': F...
# Gene           59,172  {'start': {'type': 'INTEGER', 'indexed': False...
# Gtex               53  {'tissue': {'type': 'STRING', 'indexed': True,...
# Gwas           21,281  {'note': {'type': 'STRING', 'indexed': False, ...
# Literature  1,871,731  {'pubmed_id': {'type': 'STRING', 'indexed': Tr...
# MeshTerm       29,380  {'ui': {'type': 'STRING', 'indexed': True, 'un...
# MeshTree       58,744  {'id': {'type': 'STRING', 'indexed': True, 'un...
# Pathway         2,179  {'in_disease': {'type': 'STRING', 'indexed': F...
# Protein        21,547  {'uniprot_id': {'type': 'STRING', 'indexed': T...
# Semmed        462,750  {'predicate': {'type': 'STRING', 'indexed': Tr...
# Snp            49,622  {'name': {'type': 'STRING', 'indexed': True, '...
# UMLS            4,682  {'name': {'type': 'STRING', 'indexed': False, ...

# %% [markdown]
# ### Meta relationships and connections
#
# We can also extract the meta relationship (edge) information, and the connections.

# %%
meta_rel_df = (
    pd.DataFrame.from_dict(metadata["edges"], orient="index").
    merge(
        pd.DataFrame.from_dict(
            {_["rel"]: _ for _ in metadata["connections"]}, orient="index")
        [["from_node", "to_node"]],
        left_index=True, right_index=True
    )
)

(
    meta_rel_df
    .sort_values(by=["from_node", "to_node"])
    .assign(count=lambda df: df["count"].apply(lambda x: f"{x:,}"))
)
# Out:
#                                  count  \
# DISEASE_TO_EFO                   1,824
# DRUG_TO_DISEASE                    158
# CPIC                               356
# OPENTARGETS_DRUG_TO_TARGET       6,045
# DRUG_TO_LITERATURE                 243
# DRUG_TO_PROTEIN                 22,438
# EFO_CHILD_OF                    26,562
# PRECEDING_EVENT                 10,418
# EXPRESSED_IN                   861,552
# XQTL_MR_GENE_GWAS           10,603,959
# XQTL_MR                      3,784,757
# EFO_EXACT                          363
# EFO_FUZZY                          452
# EFO_ZOOMA                       45,538
# GWAS_COR                        73,853
# MR                           1,727,240
# TRAIT_NLP                    2,119,498
# GWAS_TO_LITERATURE              21,281
# MESH_EXACT                         161
# MESH_FUZZY                       1,046
# MESH_MANUAL                      1,277
# METAMAP_LITE                    30,412
# SEM                          2,537,738
# MESH_TO_DISEASE                  3,318
# MESH_HIERARCHY                  58,744
# MESH_PARENT                     58,626
# EVENT_IN_PATHWAY                12,488
# PATHWAY_TO_LITERATURE            8,952
# PROTEIN_IN_EVENT                13,484
# PROTEIN_TO_LITERATURE          107,559
# PROTEIN_IN_PATHWAY               9,281
# INTACT_NOT_INTERACTS_WITH          699
# STRING_INTERACT_WITH           390,222
# INTACT_INTERACTS_WITH          188,879
# SNP_GENE                        18,408
# XQTL_MR_SNP_GENE                41,027
# MRE_STUDY_SNP                   29,767
# UMLS_SEM_OBJECT                462,750
# UMLS_SEM_SUBJECT               462,750
#
#                                                                    properties  \
# DISEASE_TO_EFO                                                           None
# DRUG_TO_DISEASE                                                          None
# CPIC                        {'pharmgkb_level_of_evidence': {'array': False...
# OPENTARGETS_DRUG_TO_TARGET  {'action_type': {'array': False, 'type': 'STRI...
# DRUG_TO_LITERATURE                                                       None
# DRUG_TO_PROTEIN             {'relation': {'array': False, 'type': 'STRING'...
# EFO_CHILD_OF                                                             None
# PRECEDING_EVENT                                                          None
# EXPRESSED_IN                       {'tpm': {'array': False, 'type': 'FLOAT'}}
# XQTL_MR_GENE_GWAS           {'p': {'array': False, 'type': 'FLOAT'}, 'rsid...
# XQTL_MR                     {'p': {'array': False, 'type': 'FLOAT'}, 'se':...
# EFO_EXACT                                                                None
# EFO_FUZZY                       {'weight': {'array': False, 'type': 'FLOAT'}}
# EFO_ZOOMA                   {'efo_confidence': {'array': False, 'type': 'S...
# GWAS_COR                           {'cor': {'array': False, 'type': 'FLOAT'}}
# MR                          {'p': {'array': False, 'type': 'FLOAT'}, 'se':...
# TRAIT_NLP                       {'cosine': {'array': False, 'type': 'FLOAT'}}
# GWAS_TO_LITERATURE                                                       None
# MESH_EXACT                                                               None
# MESH_FUZZY                                                               None
# MESH_MANUAL                                                              None
# METAMAP_LITE                     {'score': {'array': False, 'type': 'FLOAT'}}
# SEM                                                                      None
# MESH_TO_DISEASE                                                          None
# MESH_HIERARCHY                                                           None
# MESH_PARENT                                                              None
# EVENT_IN_PATHWAY                                                         None
# PATHWAY_TO_LITERATURE                                                    None
# PROTEIN_IN_EVENT                                                         None
# PROTEIN_TO_LITERATURE                                                    None
# PROTEIN_IN_PATHWAY                                                       None
# INTACT_NOT_INTERACTS_WITH   {'intact_source': {'array': True, 'type': 'STR...
# STRING_INTERACT_WITH           {'score': {'array': False, 'type': 'INTEGER'}}
# INTACT_INTERACTS_WITH       {'intact_source': {'array': True, 'type': 'STR...
# SNP_GENE                                                                 None
# XQTL_MR_SNP_GENE                                                         None
# MRE_STUDY_SNP               {'se': {'array': False, 'type': 'FLOAT'}, 'eaf...
# UMLS_SEM_OBJECT                                                          None
# UMLS_SEM_SUBJECT                                                         None
#
#                              from_node     to_node
# DISEASE_TO_EFO                 Disease         Efo
# DRUG_TO_DISEASE                   Drug     Disease
# CPIC                              Drug        Gene
# OPENTARGETS_DRUG_TO_TARGET        Drug        Gene
# DRUG_TO_LITERATURE                Drug  Literature
# DRUG_TO_PROTEIN                   Drug     Protein
# EFO_CHILD_OF                       Efo         Efo
# PRECEDING_EVENT                  Event       Event
# EXPRESSED_IN                      Gene        Gtex
# XQTL_MR_GENE_GWAS                 Gene        Gwas
# XQTL_MR                           Gene        Gwas
# EFO_EXACT                         Gwas         Efo
# EFO_FUZZY                         Gwas         Efo
# EFO_ZOOMA                         Gwas         Efo
# GWAS_COR                          Gwas        Gwas
# MR                                Gwas        Gwas
# TRAIT_NLP                         Gwas        Gwas
# GWAS_TO_LITERATURE                Gwas  Literature
# MESH_EXACT                        Gwas    MeshTerm
# MESH_FUZZY                        Gwas    MeshTerm
# MESH_MANUAL                       Gwas    MeshTerm
# METAMAP_LITE                      Gwas        UMLS
# SEM                         Literature      Semmed
# MESH_TO_DISEASE               MeshTerm     Disease
# MESH_HIERARCHY                MeshTerm    MeshTree
# MESH_PARENT                   MeshTree    MeshTree
# EVENT_IN_PATHWAY               Pathway       Event
# PATHWAY_TO_LITERATURE          Pathway  Literature
# PROTEIN_IN_EVENT               Protein       Event
# PROTEIN_TO_LITERATURE          Protein  Literature
# PROTEIN_IN_PATHWAY             Protein     Pathway
# INTACT_NOT_INTERACTS_WITH      Protein     Protein
# STRING_INTERACT_WITH           Protein     Protein
# INTACT_INTERACTS_WITH          Protein     Protein
# SNP_GENE                           Snp        Gene
# XQTL_MR_SNP_GENE                   Snp        Gene
# MRE_STUDY_SNP                      Snp        Gwas
# UMLS_SEM_OBJECT                   UMLS      Semmed
# UMLS_SEM_SUBJECT                  UMLS      Semmed

# %% [markdown]
# ### Schema plot

# %% [markdown]
# We can generate a network diagram of the graph db schema using `networkx`.

# %%
graph = nx.from_pandas_edgelist(
    meta_rel_df,
    source="from_node", target="to_node"
)

# %%
nx.draw(
    G=graph,
    pos=nx.kamada_kawai_layout(graph),
    with_labels=True,
    node_color="white")

# %% [markdown]
# A detailed version of the shema plot can be obtained from the API:
#
# ![schema_plot](http://ieu-mrbssd1.epi.bris.ac.uk:28046/meta/schema?graphviz=true&plot=true)

# %% [markdown]
# ## Search for specific node

# %% [markdown]
# Users can use [the explorer on the Web UI](http://dev.epigraphdb.org/explore) to search for a specific node by:
#
# - fuzzy matching by "name" field.
# - exact matching by "ID" field if you know the its ID (e.g. the ID to a GWAS from IEU GWAS Database).
#
# Here we show how these are done at the API level using `Gwas` nodes as an example.

# %% [markdown]
# First we need to know what the "ID" and "name" fields are for the meta nodes using `GET /meta/nodes/id-name-schema`:

# %%
r = requests.get(f"{API_URL}/meta/nodes/id-name-schema")
r.raise_for_status()

meta_node_fields = r.json()
meta_node_fields
# Out:
# {'Disease': {'id': 'id', 'name': 'label'},
#  'Drug': {'id': 'label', 'name': 'label'},
#  'Efo': {'id': 'id', 'name': 'value'},
#  'Event': {'id': 'reactome_id', 'name': 'name'},
#  'Gene': {'id': 'ensembl_id', 'name': 'name'},
#  'Gtex': {'id': 'tissue', 'name': 'tissue'},
#  'Gwas': {'id': 'id', 'name': 'trait'},
#  'Literature': {'id': 'pubmed_id', 'name': 'pubmed_id'},
#  'Pathway': {'id': 'reactome_id', 'name': 'name'},
#  'Protein': {'id': 'uniprot_id', 'name': 'uniprot_id'},
#  'SemmedTerm': {'id': 'id', 'name': 'name'},
#  'Variant': {'id': 'name', 'name': 'name'}}

# %% [markdown]
# ### Fuzzy matching

# %% [markdown]
# Here we search for nodes can contain "body mass index" in their traits.

# %%
name = "body mass index"

r = requests.get(f"{API_URL}/meta/nodes/Gwas/search", params={"name": name})
r.raise_for_status()

print(pformat(r.json())[:3000])
# Out:
# {'metadata': {'empty_results': False,
#               'query': 'MATCH (node: Gwas) WHERE node.trait =~ "(?i).*body '
#                        'mass index.*" RETURN node LIMIT 10;',
#               'total_seconds': 0.127409},
#  'results': [{'node': {'access': 'public',
#                        'author': 'Locke AE',
#                        'category': 'Risk factor',
#                        'consortium': 'NA',
#                        'id': 'ieu-a-2',
#                        'mr': '1',
#                        'nsnp': '2555511',
#                        'pmid': '25673413',
#                        'population': 'Mixed',
#                        'priority': '1',
#                        'sample_size': '339224',
#                        'sd': '4.77',
#                        'sex': 'Males and Females',
#                        'subcategory': 'Anthropometric',
#                        'trait': 'Body mass index',
#                        'unit': 'NA',
#                        'year': '2015'}},
#              {'node': {'access': 'public',
#                        'author': 'Locke AE',
#                        'category': 'Risk factor',
#                        'consortium': 'NA',
#                        'id': 'ieu-a-974',
#                        'mr': '1',
#                        'nsnp': '2494613',
#                        'pmid': '25673413',
#                        'population': 'European',
#                        'priority': '4',
#                        'sample_size': '171977',
#                        'sd': '4.77',
#                        'sex': 'Females',
#                        'subcategory': 'Anthropometric',
#                        'trait': 'Body mass index',
#                        'unit': 'NA',
#                        'year': '2015'}},
#              {'node': {'access': 'public',
#                        'author': 'Randall JC',
#                        'category': 'Risk factor',
#                        'consortium': 'NA',
#                        'id': 'ieu-a-95',
#                        'mr': '1',
#                        'nsnp': '2736876',
#                        'pmid': '23754948',
#                        'population': 'European',
#                        'priority': '6',
#                        'sample_size': '73137',
#                        'sd': '4.77',
#                        'sex': 'Females',
#                        'subcategory': 'Anthropometric',
#                        'trait': 'Body mass index',
#                        'unit': 'NA',
#                        'year': '2013'}},
#              {'node': {'access': 'public',
#                        'author': 'Hoffmann TJ',
#                        'category': 'NA',
#                        'consortium': 'NA',
#                        'id': 'ebi-a-GCST006368',
#                        'mr': '1',
#                        'note': 'NA',
#                        'nsnp': '27854527',
#                        'pmid': '30108127',
#                        'population': 'European',
#                        'priority': '0',
#                        'sample_size': '315347',
#                        'sex': 'N

# %% [markdown]
# ### Exact matching

# %% [markdown]
# Similarly, we can exact match a specific node by its ID.

# %%
id = "ieu-a-2"

r = requests.get(f"{API_URL}/meta/nodes/Gwas/search", params={"id": id})
r.raise_for_status()

print(pformat(r.json())[:3000])
# Out:
# {'metadata': {'empty_results': False,
#               'query': 'MATCH (node: Gwas {id: "ieu-a-2"}) RETURN node LIMIT '
#                        '10;',
#               'total_seconds': 0.003239},
#  'results': [{'node': {'access': 'public',
#                        'author': 'Locke AE',
#                        'category': 'Risk factor',
#                        'consortium': 'NA',
#                        'id': 'ieu-a-2',
#                        'mr': '1',
#                        'nsnp': '2555511',
#                        'pmid': '25673413',
#                        'population': 'Mixed',
#                        'priority': '1',
#                        'sample_size': '339224',
#                        'sd': '4.77',
#                        'sex': 'Males and Females',
#                        'subcategory': 'Anthropometric',
#                        'trait': 'Body mass index',
#                        'unit': 'NA',
#                        'year': '2015'}}]}

# %% [markdown]
# ## Cypher (advanced)

# %% [markdown]
# Advanced users that are familiar with Neo4j Cypher can query the database using Cypher directly.

# %%
query = """
    MATCH (exposure:Gwas)-[mr:MR]->(outcome:Gwas) 
    WHERE exposure.trait = "Body mass index"
    RETURN exposure, outcome, mr LIMIT 2
"""

r = requests.post(f"{API_URL}/cypher", json={"query": query})
r.raise_for_status()

print(pformat(r.json())[:3000])
# Out:
# {'metadata': {'empty_results': False,
#               'query': 'MATCH (exposure:Gwas)-[mr:MR]->(outcome:Gwas) WHERE '
#                        'exposure.trait = "Body mass index" RETURN exposure, '
#                        'outcome, mr LIMIT 2',
#               'total_seconds': 0.259296},
#  'results': [{'exposure': {'access': 'public',
#                            'author': 'Locke AE',
#                            'category': 'Risk factor',
#                            'consortium': 'NA',
#                            'id': 'ieu-a-2',
#                            'mr': '1',
#                            'nsnp': '2555511',
#                            'pmid': '25673413',
#                            'population': 'Mixed',
#                            'priority': '1',
#                            'sample_size': '339224',
#                            'sd': '4.77',
#                            'sex': 'Males and Females',
#                            'subcategory': 'Anthropometric',
#                            'trait': 'Body mass index',
#                            'unit': 'NA',
#                            'year': '2015'},
#               'mr': {'b': 0.6141663193702698,
#                      'ci_low': 0.5722519159317017,
#                      'ci_upp': 0.6560807824134827,
#                      'log10pval': 40.0,
#                      'method': 'Simple mean',
#                      'moescore': 0.9200000166893005,
#                      'nsnp': 73,
#                      'pval': 3.5982541966932653e-41,
#                      'se': 0.021384920924901962,
#                      'selection': 'HF'},
#               'outcome': {'access': 'public',
#                           'author': 'Lu',
#                           'category': 'Risk factor',
#                           'consortium': 'NA',
#                           'id': 'ieu-a-999',
#                           'mr': '1',
#                           'note': '89% European. SD value corresponds to '
#                                   'original distribution',
#                           'nsnp': '3228665',
#                           'pmid': '26833246',
#                           'population': 'European',
#                           'priority': '1',
#                           'sample_size': '100716',
#                           'sd': '6.81',
#                           'sex': 'Males and Females',
#                           'subcategory': 'Anthropometric',
#                           'trait': 'Body fat',
#                           'unit': 'NA',
#                           'year': '2016'}},
#              {'exposure': {'access': 'public',
#                            'author': 'Locke AE',
#                            'category': 'Risk factor',
#                            'consortium': 'NA',
#                            'id': 'ieu-a-2',
#                            'mr': '1',
#                            'nsnp': '2555511',
#                            'pmid': '25673413',
#                            'population': 'Mixed',
#                            'priority': '1',
#                            'sample_size': '339224',

# %% [markdown]
# Alternatively we provide an endpoint `POST /cypher/builder/plain` that assist users in querying for simple cypher queries.

# %%
payload = {
    "source_meta_node": "Gwas",
    "target_meta_node": "Gwas",
    "meta_rel": "MR",
    "where": ["source_node.trait = 'Body mass index'"],
    "limit": 2
}

r = requests.post(f"{API_URL}/cypher/builder/plain", json=payload)
r.raise_for_status()

print(pformat(r.json())[:3000])
# Out:
# {'metadata': {'empty_results': False,
#               'query': 'MATCH (source_node:Gwas) -[rel:MR]- (target_node:Gwas) '
#                        "WHERE source_node.trait = 'Body mass index' RETURN "
#                        'source_node, rel, target_node LIMIT 2',
#               'total_seconds': 0.031114},
#  'results': [{'rel': {'b': 0.0030348598957061768,
#                       'ci_low': -0.002742477459833026,
#                       'ci_upp': 0.008812196552753448,
#                       'log10pval': 1.0,
#                       'method': 'Weighted median',
#                       'moescore': 0.7799999713897705,
#                       'nsnp': 77,
#                       'pval': 0.3032084107398987,
#                       'se': 0.002947675297036767,
#                       'selection': 'DF + HF'},
#               'source_node': {'access': 'public',
#                               'author': 'Locke AE',
#                               'category': 'Risk factor',
#                               'consortium': 'NA',
#                               'id': 'ieu-a-2',
#                               'mr': '1',
#                               'nsnp': '2555511',
#                               'pmid': '25673413',
#                               'population': 'Mixed',
#                               'priority': '1',
#                               'sample_size': '339224',
#                               'sd': '4.77',
#                               'sex': 'Males and Females',
#                               'subcategory': 'Anthropometric',
#                               'trait': 'Body mass index',
#                               'unit': 'NA',
#                               'year': '2015'},
#               'target_node': {'access': 'public',
#                               'author': 'Neale',
#                               'category': 'NA',
#                               'consortium': 'Neale Lab',
#                               'id': 'ukb-a-99',
#                               'mr': '1',
#                               'ncase': '8718',
#                               'ncontrol': '328441',
#                               'note': 'NA',
#                               'nsnp': '10894596',
#                               'population': 'European',
#                               'priority': '1',
#                               'sample_size': '337159',
#                               'sex': 'Males and Females',
#                               'subcategory': 'NA',
#                               'trait': 'Non-cancer illness code  '
#                                        'self-reported: eczema/dermatitis',
#                               'unit': 'SD',
#                               'year': '2017'}},
#              {'rel': {'b': -3.053751788684167e-05,
#                       'ci_low': -0.00041146361036226153,
#                       'ci_upp': 0.00035038855276070535,
#                       'log10pval': 0.0,
#                       'method': 'RE IVW',
#                       'moescore': 0.800000011920929,
#                       'nsnp': 79,
#                       'pval'

# %% [markdown]
# Again for the detailed documentation on the API endpoints please visit:
#
# - The Swagger interface: http://api.epigraphdb.org
# - The sections regarding API endpoints on the documentation site: http://docs.epigraphdb.org/api/api-endpoints/
